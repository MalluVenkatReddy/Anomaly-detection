# %%
Q1. What is anomaly detection and what is its purpose?

# %% [markdown]
# #### Anomaly detection identifies suspicious activity that falls outside of your established normal patterns of behavior

# %%
Q2. What are the key challenges in anomaly detection?

# %% [markdown]
# #### challenges in anomaly detection:
#
# -- Challenge #1: Data quality
#
# -- Challenge #2: Training sample sizes
#
# -- Challenge #3: False alerting
#
# --Challenge #4: Imbalanced distributions

# %%
Q3. How does unsupervised anomaly detection differ from supervised anomaly detection?

# %% [markdown]
# #### Unsupervised anomaly detection techniques assume the data is unlabelled and are by far the most commonly used due to their wider and relevant application.

# %%
Q4. What are the main categories of anomaly detection algorithms?

# %% [markdown]
# #### There are three main classes of anomaly detection techniques: unsupervised, semi-supervised, and supervised. Essentially, the correct anomaly detection method depends on the available labels in the dataset.

# %%
Q5. What are the main assumptions made by distance-based anomaly detection methods?

# %% [markdown]
# #### Number of normal observation is much more than the number of abnormal observations(anomalies) in data.

# %%
Q6. How does the LOF algorithm compute anomaly scores?

# %% [markdown]
# #### The Local Outlier Factor (LOF) algorithm is an unsupervised anomaly detection method which computes the local density deviation of a given data point with respect to its neighbors. It considers as outliers the samples that have a substantially lower density than their neighbors.

# %%
from IPython import display
display.Image("Anomoly score.png")

# %%
Q7. What are the key parameters of the Isolation Forest algorithm?

# %% [markdown]
# #### contamination is the key parameter of the Isolation Forest algorithm

# %%
Q8. If a data point has only 2 neighbours of the same class within a radius of 0.5, what is its anomaly score 
using KNN with K=10?

# %% [markdown]
# -- anomaly score is 1 using KNN with K=10

# %%
Q9. Using the Isolation Forest algorithm with 100 trees and a dataset of 3000 data points, what is the 
anomaly score for a data point that has an average path length of 5.0 compared to the average path 
length of the trees?
